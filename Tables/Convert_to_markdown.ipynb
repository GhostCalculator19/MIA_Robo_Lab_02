# %% [markdown]
# ## Результаты без обработки

# %%
import pandas as pd

# Load your CSV
df = pd.read_csv("Results_Non_norm.csv")

# Print the data as a Markdown table
print(df.to_markdown(index=False))
# Out:
# | Признаки   |   CV Accuracy |   Accuracy |   F1-score |   Recall (Тип 5) |   Precision (Тип 5) |
# |:-----------|--------------:|-----------:|-----------:|-----------------:|--------------------:|
# | V1         |        0.6591 |     0.6136 |     0.2766 |           0.3611 |              0.2241 |
# | V2         |        0.7273 |     0.608  |     0.2737 |           0.3611 |              0.2203 |
# | V1+V2      |        0.7557 |     0.7898 |     0.0513 |           0.0278 |              0.3333 |

# %% [markdown]
# ## Результаты с Нормализацией V1

# %%
# Load your CSV
df_v1 = pd.read_csv("Results_V1_norm.csv")

# Print the data as a Markdown table
df_v1 = df_v1.drop(columns=['model'])
print(df_v1.to_markdown(index=False))
# Out:
# | Dataset   | Config          | Hidden Layers   | Activation   | Solver   |     CV |   CV std |   Accuracy |     F1 |
# |:----------|:----------------|:----------------|:-------------|:---------|-------:|---------:|-----------:|-------:|
# | V1        | Базовая         | (50, 25)        | relu         | adam     | 0.8295 |   0.0377 |     0.9943 | 0.9859 |
# | V1        | Больше нейронов | (100, 50)       | relu         | adam     | 0.8295 |   0.0341 |     1      | 1      |
# | V1        | Функция tanh    | (50, 25)        | tanh         | adam     | 0.7955 |   0      |     0.7955 | 0      |
# | V1        | 3 скрытых слоя  | (30, 15, 10)    | relu         | adam     | 0.8409 |   0.0161 |     0.7955 | 0      |
# | V1        | Solver lbfgs    | (50, 25)        | relu         | lbfgs    | 0.8011 |   0.076  |     1      | 1      |

# %% [markdown]
# ## Результаты с Нормализацией V2

# %%
# Load your CSV
df_v2 = pd.read_csv("Results_V2_norm.csv")

# Print the data as a Markdown table
df_v2 = df_v2.drop(columns=['model'])
print(df_v2.to_markdown(index=False))
# Out:
# | Dataset   | Config          | Hidden Layers   | Activation   | Solver   |     CV |   CV std |   Accuracy |     F1 |
# |:----------|:----------------|:----------------|:-------------|:---------|-------:|---------:|-----------:|-------:|
# | V2        | Базовая         | (50, 25)        | relu         | adam     | 0.8239 |   0.0336 |     0.9318 | 0.8286 |
# | V2        | Больше нейронов | (100, 50)       | relu         | adam     | 0.7614 |   0.041  |     0.9943 | 0.9863 |
# | V2        | Функция tanh    | (50, 25)        | tanh         | adam     | 0.7955 |   0      |     0.7955 | 0      |
# | V2        | 3 скрытых слоя  | (30, 15, 10)    | relu         | adam     | 0.8011 |   0.067  |     0.9886 | 0.9722 |
# | V2        | Solver lbfgs    | (50, 25)        | relu         | lbfgs    | 0.7727 |   0.0533 |     1      | 1      |

# %% [markdown]
# ## Результаты с нормализацией V1 + V2

# %%
# Load your CSV
df_v1v2 = pd.read_csv("Results_V1+V2_norm.csv")

# Print the data as a Markdown table
df_v1v2 = df_v1v2.drop(columns=['model'])
print(df_v1v2.to_markdown(index=False))
# Out:
# | Dataset   | Config          | Hidden Layers   | Activation   | Solver   |     CV |   CV std |   Accuracy |     F1 |
# |:----------|:----------------|:----------------|:-------------|:---------|-------:|---------:|-----------:|-------:|
# | V1+V2     | Базовая         | (50, 25)        | relu         | adam     | 0.858  |   0.067  |     1      | 1      |
# | V1+V2     | Больше нейронов | (100, 50)       | relu         | adam     | 0.875  |   0.0469 |     1      | 1      |
# | V1+V2     | Функция tanh    | (50, 25)        | tanh         | adam     | 0.8466 |   0.0188 |     0.9716 | 0.9315 |
# | V1+V2     | 3 скрытых слоя  | (30, 15, 10)    | relu         | adam     | 0.8636 |   0.0682 |     1      | 1      |
# | V1+V2     | Solver lbfgs    | (50, 25)        | relu         | lbfgs    | 0.8466 |   0.065  |     1      | 1      |

# %% [markdown]
# ### Результаты лучших моделей V1, V2 и V1+V2

# %%
# Load your CSV
df_best_models = pd.read_csv("Best_models_V1_V2_V1+V2.csv")

# Print the data as a Markdown table
df_best_models = df_best_models.drop(columns=['model'])
print(df_best_models.to_markdown(index=False))
# Out:
# | Dataset   | Config          | Hidden Layers   | Activation   | Solver   |     CV |   CV std |   Accuracy |   F1 |
# |:----------|:----------------|:----------------|:-------------|:---------|-------:|---------:|-----------:|-----:|
# | V1        | Больше нейронов | (100, 50)       | relu         | adam     | 0.8295 |   0.0341 |          1 |    1 |
# | V1+V2     | Базовая         | (50, 25)        | relu         | adam     | 0.858  |   0.067  |          1 |    1 |
# | V2        | Solver lbfgs    | (50, 25)        | relu         | lbfgs    | 0.7727 |   0.0533 |          1 |    1 |
